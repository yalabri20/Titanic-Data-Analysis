# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.describe(exclude="number")
# Out:
#          sex embarked  class  who adult_male deck  embark_town alive alone
# count    891      889    891  891        891  203          889   891   891
# unique     2        3      3    3          2    7            3     2     2
# top     male        S  Third  man       True    C  Southampton    no  True
# freq     577      644    491  537        537   59          644   549   537

# %%
titanic.deck.value_counts()
# Out:
# deck
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: count, dtype: int64

# %%
sns.displot(data=titanic , x="age", col="survived")

# %%
plt.pie(titanic.survived.value_counts() , labels=titanic.survived.value_counts().index , autopct="%1.2f%%" )
# Out:
# ([<matplotlib.patches.Wedge at 0x1ae34c00080>,
# ...
#  [Text(-0.3925749350994583, 1.0275626113924428, '0'),
#   Text(0.3925750313068116, -1.0275625746369201, '1')],
#  [Text(-0.21413178278152267, 0.5604886971231505, '61.62%'),
#   Text(0.21413183525826085, -0.5604886770746836, '38.38%')])

# %%
sns.lineplot(data=titanic, x="survived" ,y="age")
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.scatterplot(data=titanic , x="fare", y="age")
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.barplot(data=titanic, x="embark_town",y="age", hue="survived")
# Out:
# <Axes: xlabel='embark_town', ylabel='age'>

# %%
sns.histplot(data=titanic, x="who", hue="deck", multiple="dodge")
# Out:
# <Axes: xlabel='who', ylabel='Count'>

# %%
sns.histplot(data=titanic, x="who", hue="alive", multiple="dodge")
# Out:
# <Axes: xlabel='who', ylabel='Count'>

# %%
sns.scatterplot(data=titanic, x="fare",y="age",hue="sex")
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.catplot(data=titanic ,x="deck" ,y="age" ,hue="survived",  kind="bar",  col="who")
